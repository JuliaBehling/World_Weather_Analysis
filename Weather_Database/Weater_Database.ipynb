# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# 3.New set of 2,000 random latitudes and longitudes

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# 4. Import CityPy and find the nearest cities
from citipy import citipy

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# 5. Perform an API with the Open Weather Map

#Import dependencies
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# 6. Retrieve the following information from the API Call
city_data = []

#Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters
record_count = 1
set_count = 1

#Loop through all the cities in our list
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    #Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    #Add 1 toS the record count
    record_count += 1


#Run an API request for each of the cites 
    try:
        #Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        #Convert the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        #Append the city information into city_data list
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat, 
                          'Lng': city_lng, 
                          'Max Temp': city_max_temp, 
                          'Humidity': city_humidity, 
                          'Cloudiness': city_clouds, 
                          'Wind Speed': city_wind, 
                          'Current Description': city_description})

    except:
        print("City not found. Skipping...")
        pass

#Indicate that the Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | axim
# Processing Record 3 of Set 1 | saint anthony
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | karema
# Processing Record 6 of Set 1 | waverley
# Processing Record 7 of Set 1 | oga
# Processing Record 8 of Set 1 | coquimbo
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | airai
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 1 | kloulklubed
# Processing Record 15 of Set 1 | bronnoysund
# Processing Record 16 of Set 1 | bukama
# Processing Record 17 of Set 1 | burica
# City not found. Skipping...
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | balkanabat
# Processing Record 20 of Set 1 | lebu
# Processing Record 21 of Set 1 | jimo
# Processing Record 22 of Set 1 | salalah
# Processing Record 23 of Set 1 | bulungu
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | keffi
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | inuvik
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | westport
# Processing Record 31 of Set 1 | saldanha
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | grand gaube
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | boyolangu
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | provideniya
# Processing Record 39 of Set 1 | batagay
# Processing Record 40 of Set 1 | north bend
# Processing Record 41 of Set 1 | victoria
# Processing Record 42 of Set 1 | umm durman
# City not found. Skipping...
# Processing Record 43 of Set 1 | lokosovo
# Processing Record 44 of Set 1 | yongan
# Processing Record 45 of Set 1 | mar del plata
# Processing Record 46 of Set 1 | puerto ayora
# Processing Record 47 of Set 1 | tautira
# Processing Record 48 of Set 1 | nhulunbuy
# Processing Record 49 of Set 1 | brae
# Processing Record 50 of Set 1 | east london
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | naraina
# Processing Record 3 of Set 2 | rocha
# Processing Record 4 of Set 2 | dokri
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | vila franca do campo
# Processing Record 7 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 2 | cidreira
# Processing Record 9 of Set 2 | henties bay
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | alta floresta
# Processing Record 12 of Set 2 | havelock
# Processing Record 13 of Set 2 | lagoa
# Processing Record 14 of Set 2 | karsava
# Processing Record 15 of Set 2 | shetpe
# Processing Record 16 of Set 2 | bengkulu
# Processing Record 17 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | port alfred
# Processing Record 20 of Set 2 | adrar
# Processing Record 21 of Set 2 | los llanos de aridane
# Processing Record 22 of Set 2 | luderitz
# Processing Record 23 of Set 2 | aragyukh
# City not found. Skipping...
# Processing Record 24 of Set 2 | ligayan
# Processing Record 25 of Set 2 | barrow
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | ambanja
# Processing Record 28 of Set 2 | san joaquin
# Processing Record 29 of Set 2 | korla
# Processing Record 30 of Set 2 | caibarien
# Processing Record 31 of Set 2 | rio gallegos
# Processing Record 32 of Set 2 | hamilton
# Processing Record 33 of Set 2 | husavik
# Processing Record 34 of Set 2 | hirara
# Processing Record 35 of Set 2 | salinopolis
# Processing Record 36 of Set 2 | poso
# Processing Record 37 of Set 2 | sumbe
# Processing Record 38 of Set 2 | yulara
# Processing Record 39 of Set 2 | wucheng
# Processing Record 40 of Set 2 | cabo san lucas
# Processing Record 41 of Set 2 | tiksi
# Processing Record 42 of Set 2 | hervey bay
# Processing Record 43 of Set 2 | arraial do cabo
# Processing Record 44 of Set 2 | dikson
# Processing Record 45 of Set 2 | talcahuano
# Processing Record 46 of Set 2 | ilebo
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | hun
# Processing Record 49 of Set 2 | tuktoyaktuk
# Processing Record 50 of Set 2 | suzun
# Processing Record 1 of Set 3 | vaitape
# Processing Record 2 of Set 3 | northam
# Processing Record 3 of Set 3 | kirtipur
# Processing Record 4 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 3 | ortakoy
# Processing Record 6 of Set 3 | faanui
# Processing Record 7 of Set 3 | kodiak
# Processing Record 8 of Set 3 | jamestown
# Processing Record 9 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 3 | waharoa
# Processing Record 11 of Set 3 | severo-kurilsk
# Processing Record 12 of Set 3 | ilulissat
# Processing Record 13 of Set 3 | tete
# Processing Record 14 of Set 3 | bethel
# Processing Record 15 of Set 3 | bambous virieux
# Processing Record 16 of Set 3 | bay saint louis
# Processing Record 17 of Set 3 | bonthe
# Processing Record 18 of Set 3 | dwarka
# Processing Record 19 of Set 3 | lhuntshi
# City not found. Skipping...
# Processing Record 20 of Set 3 | caravelas
# Processing Record 21 of Set 3 | batagay-alyta
# Processing Record 22 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 3 | jarvenpaa
# Processing Record 24 of Set 3 | torbay
# Processing Record 25 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 3 | parintins
# Processing Record 27 of Set 3 | kizilskoye
# Processing Record 28 of Set 3 | padang
# Processing Record 29 of Set 3 | sasovo
# Processing Record 30 of Set 3 | mantua
# Processing Record 31 of Set 3 | eldorado
# Processing Record 32 of Set 3 | chaa-khol
# City not found. Skipping...
# Processing Record 33 of Set 3 | constitucion
# Processing Record 34 of Set 3 | kavaratti
# Processing Record 35 of Set 3 | saint-philippe
# Processing Record 36 of Set 3 | jizan
# Processing Record 37 of Set 3 | mailsi
# Processing Record 38 of Set 3 | san cristobal
# Processing Record 39 of Set 3 | komsomolskiy
# Processing Record 40 of Set 3 | baykit
# Processing Record 41 of Set 3 | touros
# Processing Record 42 of Set 3 | fairbanks
# Processing Record 43 of Set 3 | kamareddi
# Processing Record 44 of Set 3 | malakal
# Processing Record 45 of Set 3 | vestmanna
# Processing Record 46 of Set 3 | half moon bay
# Processing Record 47 of Set 3 | carnarvon
# Processing Record 48 of Set 3 | chinsali
# Processing Record 49 of Set 3 | birao
# Processing Record 50 of Set 3 | dali
# Processing Record 1 of Set 4 | wenatchee
# Processing Record 2 of Set 4 | qaanaaq
# Processing Record 3 of Set 4 | povenets
# Processing Record 4 of Set 4 | avarua
# Processing Record 5 of Set 4 | pevek
# Processing Record 6 of Set 4 | nanortalik
# Processing Record 7 of Set 4 | hithadhoo
# Processing Record 8 of Set 4 | gorontalo
# Processing Record 9 of Set 4 | acari
# Processing Record 10 of Set 4 | quelimane
# Processing Record 11 of Set 4 | trinidad
# Processing Record 12 of Set 4 | fortuna
# Processing Record 13 of Set 4 | abu kamal
# Processing Record 14 of Set 4 | kirakira
# Processing Record 15 of Set 4 | birjand
# Processing Record 16 of Set 4 | coihaique
# Processing Record 17 of Set 4 | sitka
# Processing Record 18 of Set 4 | glenwood springs
# Processing Record 19 of Set 4 | ribeira grande
# Processing Record 20 of Set 4 | wenling
# Processing Record 21 of Set 4 | beringovskiy
# Processing Record 22 of Set 4 | zlotow
# Processing Record 23 of Set 4 | norman wells
# Processing Record 24 of Set 4 | longyearbyen
# Processing Record 25 of Set 4 | ulladulla
# Processing Record 26 of Set 4 | shimoda
# Processing Record 27 of Set 4 | zorgo
# Processing Record 28 of Set 4 | albany
# Processing Record 29 of Set 4 | cayenne
# Processing Record 30 of Set 4 | baruun-urt
# Processing Record 31 of Set 4 | nome
# Processing Record 32 of Set 4 | sao filipe
# Processing Record 33 of Set 4 | narsaq
# Processing Record 34 of Set 4 | leningradskiy
# Processing Record 35 of Set 4 | kaitangata
# Processing Record 36 of Set 4 | shelburne
# Processing Record 37 of Set 4 | angoche
# Processing Record 38 of Set 4 | bay roberts
# Processing Record 39 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 4 | grindavik
# Processing Record 41 of Set 4 | manicore
# Processing Record 42 of Set 4 | saint-joseph
# Processing Record 43 of Set 4 | karaton
# Processing Record 44 of Set 4 | guilin
# Processing Record 45 of Set 4 | boralday
# Processing Record 46 of Set 4 | micheweni
# Processing Record 47 of Set 4 | tyrma
# Processing Record 48 of Set 4 | solnechnyy
# Processing Record 49 of Set 4 | castro
# Processing Record 50 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 1 of Set 5 | ahipara
# Processing Record 2 of Set 5 | muskogee
# Processing Record 3 of Set 5 | placido de castro
# Processing Record 4 of Set 5 | atar
# Processing Record 5 of Set 5 | killarney
# Processing Record 6 of Set 5 | clyde river
# Processing Record 7 of Set 5 | praia da vitoria
# Processing Record 8 of Set 5 | aloleng
# Processing Record 9 of Set 5 | katherine
# Processing Record 10 of Set 5 | suez
# Processing Record 11 of Set 5 | umm lajj
# Processing Record 12 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 5 | cherskiy
# Processing Record 14 of Set 5 | buala
# Processing Record 15 of Set 5 | gari
# Processing Record 16 of Set 5 | tura
# Processing Record 17 of Set 5 | sur
# Processing Record 18 of Set 5 | port lincoln
# Processing Record 19 of Set 5 | ostrovnoy
# Processing Record 20 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 21 of Set 5 | bathsheba
# Processing Record 22 of Set 5 | tuatapere
# Processing Record 23 of Set 5 | marystown
# Processing Record 24 of Set 5 | pombia
# Processing Record 25 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 5 | encheng
# Processing Record 27 of Set 5 | belaya gora
# Processing Record 28 of Set 5 | balabac
# Processing Record 29 of Set 5 | chabahar
# Processing Record 30 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 5 | taylors
# Processing Record 32 of Set 5 | christchurch
# Processing Record 33 of Set 5 | chokurdakh
# Processing Record 34 of Set 5 | isangel
# Processing Record 35 of Set 5 | navolato
# Processing Record 36 of Set 5 | shubarshi
# Processing Record 37 of Set 5 | tongren
# Processing Record 38 of Set 5 | burnie
# Processing Record 39 of Set 5 | yerbogachen
# Processing Record 40 of Set 5 | waipawa
# Processing Record 41 of Set 5 | qostanay
# Processing Record 42 of Set 5 | qui nhon
# Processing Record 43 of Set 5 | iqaluit
# Processing Record 44 of Set 5 | santander de quilichao
# Processing Record 45 of Set 5 | kichmengskiy gorodok
# Processing Record 46 of Set 5 | dunda
# Processing Record 47 of Set 5 | mahebourg
# Processing Record 48 of Set 5 | nikolskoye
# Processing Record 49 of Set 5 | honiara
# Processing Record 50 of Set 5 | nueve de julio
# Processing Record 1 of Set 6 | sabang
# Processing Record 2 of Set 6 | chapais
# Processing Record 3 of Set 6 | yialos
# City not found. Skipping...
# Processing Record 4 of Set 6 | kibre mengist
# Processing Record 5 of Set 6 | pulandian
# Processing Record 6 of Set 6 | kolokani
# Processing Record 7 of Set 6 | santa cruz de la palma
# Processing Record 8 of Set 6 | tual
# Processing Record 9 of Set 6 | lazaro cardenas
# Processing Record 10 of Set 6 | college
# Processing Record 11 of Set 6 | ponta do sol
# Processing Record 12 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 6 | tasiilaq
# Processing Record 14 of Set 6 | skibotn
# Processing Record 15 of Set 6 | talcher
# Processing Record 16 of Set 6 | nova venecia
# Processing Record 17 of Set 6 | agadez
# Processing Record 18 of Set 6 | hualmay
# Processing Record 19 of Set 6 | avera
# Processing Record 20 of Set 6 | souillac
# Processing Record 21 of Set 6 | kinanah
# City not found. Skipping...
# Processing Record 22 of Set 6 | moron
# Processing Record 23 of Set 6 | talnakh
# Processing Record 24 of Set 6 | brokopondo
# Processing Record 25 of Set 6 | flinders
# Processing Record 26 of Set 6 | cockburn town
# Processing Record 27 of Set 6 | kashary
# Processing Record 28 of Set 6 | severo-yeniseyskiy
# Processing Record 29 of Set 6 | okha
# Processing Record 30 of Set 6 | luebo
# Processing Record 31 of Set 6 | wamba
# Processing Record 32 of Set 6 | lata
# Processing Record 33 of Set 6 | riyadh
# Processing Record 34 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 6 | auki
# Processing Record 36 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 6 | klaksvik
# Processing Record 38 of Set 6 | portland
# Processing Record 39 of Set 6 | trairi
# Processing Record 40 of Set 6 | livingston
# Processing Record 41 of Set 6 | luancheng
# Processing Record 42 of Set 6 | haines junction
# Processing Record 43 of Set 6 | coro
# Processing Record 44 of Set 6 | vila velha
# Processing Record 45 of Set 6 | westpunt
# City not found. Skipping...
# Processing Record 46 of Set 6 | yar-sale
# Processing Record 47 of Set 6 | puerto penasco
# Processing Record 48 of Set 6 | hai duong
# Processing Record 49 of Set 6 | pimentel
# Processing Record 50 of Set 6 | narvik
# Processing Record 1 of Set 7 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 2 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 3 of Set 7 | hyeres
# Processing Record 4 of Set 7 | kamina
# Processing Record 5 of Set 7 | hasaki
# Processing Record 6 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 7 | tazovskiy
# Processing Record 8 of Set 7 | walvis bay
# Processing Record 9 of Set 7 | cranbrook
# Processing Record 10 of Set 7 | capoterra
# Processing Record 11 of Set 7 | thompson
# Processing Record 12 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 13 of Set 7 | upernavik
# Processing Record 14 of Set 7 | japura
# Processing Record 15 of Set 7 | saskylakh
# Processing Record 16 of Set 7 | qandahar
# City not found. Skipping...
# Processing Record 17 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 18 of Set 7 | beloha
# Processing Record 19 of Set 7 | jalu
# Processing Record 20 of Set 7 | alyangula
# Processing Record 21 of Set 7 | ijaki
# City not found. Skipping...
# Processing Record 22 of Set 7 | nioro
# Processing Record 23 of Set 7 | muncar
# Processing Record 24 of Set 7 | khatanga
# Processing Record 25 of Set 7 | labuhan
# Processing Record 26 of Set 7 | perehonivka
# Processing Record 27 of Set 7 | hami
# Processing Record 28 of Set 7 | barga
# Processing Record 29 of Set 7 | svetlogorsk
# Processing Record 30 of Set 7 | mount isa
# Processing Record 31 of Set 7 | margherita
# Processing Record 32 of Set 7 | fort dodge
# Processing Record 33 of Set 7 | thunder bay
# Processing Record 34 of Set 7 | geraldton
# Processing Record 35 of Set 7 | baryatino
# Processing Record 36 of Set 7 | akcakoca
# Processing Record 37 of Set 7 | atlantic beach
# Processing Record 38 of Set 7 | dhidhdhoo
# Processing Record 39 of Set 7 | taltal
# Processing Record 40 of Set 7 | kruisfontein
# Processing Record 41 of Set 7 | nianzishan
# Processing Record 42 of Set 7 | jinxiang
# Processing Record 43 of Set 7 | nanning
# Processing Record 44 of Set 7 | bridlington
# Processing Record 45 of Set 7 | tabas
# Processing Record 46 of Set 7 | pacific grove
# Processing Record 47 of Set 7 | tiarei
# Processing Record 48 of Set 7 | muyezerskiy
# Processing Record 49 of Set 7 | dingle
# Processing Record 50 of Set 7 | nantucket
# Processing Record 1 of Set 8 | kawalu
# Processing Record 2 of Set 8 | mayo
# Processing Record 3 of Set 8 | raton
# Processing Record 4 of Set 8 | chekhov
# Processing Record 5 of Set 8 | margate
# Processing Record 6 of Set 8 | hokitika
# Processing Record 7 of Set 8 | ardakan
# Processing Record 8 of Set 8 | lamu
# Processing Record 9 of Set 8 | kiama
# Processing Record 10 of Set 8 | hearst
# Processing Record 11 of Set 8 | goderich
# Processing Record 12 of Set 8 | kinablangan
# Processing Record 13 of Set 8 | imeni poliny osipenko
# Processing Record 14 of Set 8 | asau
# Processing Record 15 of Set 8 | forio
# Processing Record 16 of Set 8 | srandakan
# Processing Record 17 of Set 8 | port-gentil
# Processing Record 18 of Set 8 | valparaiso
# Processing Record 19 of Set 8 | diamantino
# Processing Record 20 of Set 8 | keshan
# City not found. Skipping...
# Processing Record 21 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 22 of Set 8 | la ligua
# Processing Record 23 of Set 8 | matameye
# City not found. Skipping...
# Processing Record 24 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 8 | sinnamary
# Processing Record 26 of Set 8 | hambantota
# Processing Record 27 of Set 8 | hovd
# Processing Record 28 of Set 8 | roma
# Processing Record 29 of Set 8 | sayyan
# Processing Record 30 of Set 8 | wanning
# Processing Record 31 of Set 8 | kununurra
# Processing Record 32 of Set 8 | katsuura
# Processing Record 33 of Set 8 | sola
# Processing Record 34 of Set 8 | saint-augustin
# Processing Record 35 of Set 8 | pisco
# Processing Record 36 of Set 8 | umm kaddadah
# Processing Record 37 of Set 8 | puerto escondido
# Processing Record 38 of Set 8 | urengoy
# Processing Record 39 of Set 8 | changde
# Processing Record 40 of Set 8 | ugento
# Processing Record 41 of Set 8 | alekseyevsk
# Processing Record 42 of Set 8 | nouadhibou
# Processing Record 43 of Set 8 | portobelo
# Processing Record 44 of Set 8 | iguape
# Processing Record 45 of Set 8 | terrak
# Processing Record 46 of Set 8 | orlik
# Processing Record 47 of Set 8 | shebunino
# Processing Record 48 of Set 8 | namibe
# Processing Record 49 of Set 8 | kahului
# Processing Record 50 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 9 | kamaishi
# Processing Record 2 of Set 9 | port arthur
# Processing Record 3 of Set 9 | salinas
# Processing Record 4 of Set 9 | wewak
# Processing Record 5 of Set 9 | olafsvik
# Processing Record 6 of Set 9 | srednekolymsk
# Processing Record 7 of Set 9 | springdale
# Processing Record 8 of Set 9 | okato
# Processing Record 9 of Set 9 | lerwick
# Processing Record 10 of Set 9 | dutse
# Processing Record 11 of Set 9 | itauna
# Processing Record 12 of Set 9 | acapulco
# Processing Record 13 of Set 9 | taoudenni
# Processing Record 14 of Set 9 | itaituba
# Processing Record 15 of Set 9 | porto walter
# Processing Record 16 of Set 9 | quatre cocos
# Processing Record 17 of Set 9 | deputatskiy
# Processing Record 18 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 19 of Set 9 | kikwit
# Processing Record 20 of Set 9 | masumbwe
# Processing Record 21 of Set 9 | saint-donat-de-montcalm
# Processing Record 22 of Set 9 | caconda
# Processing Record 23 of Set 9 | bilma
# Processing Record 24 of Set 9 | kimparana
# Processing Record 25 of Set 9 | paamiut
# Processing Record 26 of Set 9 | stillwater
# Processing Record 27 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 9 | mackay
# Processing Record 29 of Set 9 | inhambupe
# Processing Record 30 of Set 9 | kilindoni
# Processing Record 31 of Set 9 | new glasgow
# Processing Record 32 of Set 9 | san ignacio
# Processing Record 33 of Set 9 | yarmouth
# Processing Record 34 of Set 9 | skagastrond
# City not found. Skipping...
# Processing Record 35 of Set 9 | ketchikan
# Processing Record 36 of Set 9 | mandla
# Processing Record 37 of Set 9 | himora
# City not found. Skipping...
# Processing Record 38 of Set 9 | aklavik
# Processing Record 39 of Set 9 | edd
# Processing Record 40 of Set 9 | san patricio
# Processing Record 41 of Set 9 | gamba
# Processing Record 42 of Set 9 | kyrylivka
# Processing Record 43 of Set 9 | ajaccio
# Processing Record 44 of Set 9 | mollendo
# Processing Record 45 of Set 9 | namtsy
# Processing Record 46 of Set 9 | mana
# Processing Record 47 of Set 9 | sheopur
# Processing Record 48 of Set 9 | saint george
# Processing Record 49 of Set 9 | pangai
# Processing Record 50 of Set 9 | dawei
# Processing Record 1 of Set 10 | yumen
# Processing Record 2 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 3 of Set 10 | kashan
# Processing Record 4 of Set 10 | port macquarie
# Processing Record 5 of Set 10 | kozhva
# Processing Record 6 of Set 10 | skjervoy
# Processing Record 7 of Set 10 | sabha
# Processing Record 8 of Set 10 | emba
# Processing Record 9 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 10 | verkhnevilyuysk
# Processing Record 11 of Set 10 | vestmannaeyjar
# Processing Record 12 of Set 10 | antalaha
# Processing Record 13 of Set 10 | saint-francois
# Processing Record 14 of Set 10 | liku
# Processing Record 15 of Set 10 | bassano del grappa
# Processing Record 16 of Set 10 | qandala
# Processing Record 17 of Set 10 | toora-khem
# Processing Record 18 of Set 10 | evensk
# Processing Record 19 of Set 10 | mecca
# Processing Record 20 of Set 10 | sorland
# Processing Record 21 of Set 10 | ambilobe
# Processing Record 22 of Set 10 | mount gambier
# Processing Record 23 of Set 10 | safaga
# Processing Record 24 of Set 10 | kattivakkam
# Processing Record 25 of Set 10 | cuamba
# Processing Record 26 of Set 10 | atasu
# Processing Record 27 of Set 10 | cedar city
# Processing Record 28 of Set 10 | maragogi
# Processing Record 29 of Set 10 | jiaonan
# Processing Record 30 of Set 10 | maceio
# Processing Record 31 of Set 10 | piopio
# Processing Record 32 of Set 10 | bilibino
# Processing Record 33 of Set 10 | zaranj
# Processing Record 34 of Set 10 | thabazimbi
# Processing Record 35 of Set 10 | mulhouse
# Processing Record 36 of Set 10 | samana
# Processing Record 37 of Set 10 | vorontsovka
# Processing Record 38 of Set 10 | port blair
# Processing Record 39 of Set 10 | slyudyanka
# Processing Record 40 of Set 10 | cairns
# Processing Record 41 of Set 10 | bajil
# Processing Record 42 of Set 10 | multan
# Processing Record 43 of Set 10 | leeton
# Processing Record 44 of Set 10 | hobyo
# Processing Record 45 of Set 10 | yining
# Processing Record 46 of Set 10 | conceicao da barra
# Processing Record 47 of Set 10 | berbera
# Processing Record 48 of Set 10 | te anau
# Processing Record 49 of Set 10 | masuguru
# Processing Record 50 of Set 10 | kovur
# Processing Record 1 of Set 11 | samarai
# Processing Record 2 of Set 11 | lavrentiya
# Processing Record 3 of Set 11 | xingyi
# Processing Record 4 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 11 | san benito abad
# Processing Record 6 of Set 11 | vitoria
# Processing Record 7 of Set 11 | kushmurun
# Processing Record 8 of Set 11 | palmas
# Processing Record 9 of Set 11 | kavieng
# Processing Record 10 of Set 11 | taburi
# City not found. Skipping...
# Processing Record 11 of Set 11 | lubumbashi
# Processing Record 12 of Set 11 | esperance
# Processing Record 13 of Set 11 | qasigiannguit
# Processing Record 14 of Set 11 | kupang
# Processing Record 15 of Set 11 | nara
# Processing Record 16 of Set 11 | van
# Processing Record 17 of Set 11 | khasan
# Processing Record 18 of Set 11 | san quintin
# Processing Record 19 of Set 11 | okahandja
# Processing Record 20 of Set 11 | sulangan
# Processing Record 21 of Set 11 | viedma
# Processing Record 22 of Set 11 | selenduma
# Processing Record 23 of Set 11 | vostok
# Processing Record 24 of Set 11 | buchanan
# Processing Record 25 of Set 11 | nouakchott
# Processing Record 26 of Set 11 | mortka
# Processing Record 27 of Set 11 | tucuma
# Processing Record 28 of Set 11 | chuy
# Processing Record 29 of Set 11 | pangnirtung
# Processing Record 30 of Set 11 | oranjemund
# Processing Record 31 of Set 11 | shahr-e babak
# Processing Record 32 of Set 11 | sisimiut
# Processing Record 33 of Set 11 | shushtar
# Processing Record 34 of Set 11 | rawah
# Processing Record 35 of Set 11 | petershagen
# Processing Record 36 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 37 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 38 of Set 11 | ust-nera
# Processing Record 39 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 40 of Set 11 | boundiali
# Processing Record 41 of Set 11 | aksarka
# Processing Record 42 of Set 11 | praia
# Processing Record 43 of Set 11 | zongolica
# Processing Record 44 of Set 11 | talbahat
# Processing Record 45 of Set 11 | maniitsoq
# Processing Record 46 of Set 11 | leshukonskoye
# Processing Record 47 of Set 11 | qaqortoq
# Processing Record 48 of Set 11 | calabazar de sagua
# Processing Record 49 of Set 11 | gravdal
# Processing Record 50 of Set 11 | fernie
# Processing Record 1 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 2 of Set 12 | izumo
# Processing Record 3 of Set 12 | kodinsk
# Processing Record 4 of Set 12 | nueva loja
# Processing Record 5 of Set 12 | mushie
# Processing Record 6 of Set 12 | kozluk
# Processing Record 7 of Set 12 | krasnoselkup
# Processing Record 8 of Set 12 | banjar
# Processing Record 9 of Set 12 | ahuimanu
# Processing Record 10 of Set 12 | waddan
# Processing Record 11 of Set 12 | agogo
# Processing Record 12 of Set 12 | penzance
# Processing Record 13 of Set 12 | batemans bay
# Processing Record 14 of Set 12 | miri
# Processing Record 15 of Set 12 | tawnat
# City not found. Skipping...
# Processing Record 16 of Set 12 | bichena
# Processing Record 17 of Set 12 | wilmington
# Processing Record 18 of Set 12 | ugarcin
# City not found. Skipping...
# Processing Record 19 of Set 12 | darhan
# Processing Record 20 of Set 12 | chany
# Processing Record 21 of Set 12 | mansa
# Processing Record 22 of Set 12 | ottumwa
# Processing Record 23 of Set 12 | sioux lookout
# Processing Record 24 of Set 12 | soto la marina
# Processing Record 25 of Set 12 | usak
# Processing Record 26 of Set 12 | port hedland
# Processing Record 27 of Set 12 | havre-saint-pierre
# Processing Record 28 of Set 12 | athabasca
# Processing Record 29 of Set 12 | cordoba
# Processing Record 30 of Set 12 | mossendjo
# Processing Record 31 of Set 12 | mikun
# Processing Record 32 of Set 12 | poronaysk
# Processing Record 33 of Set 12 | ust-koksa
# Processing Record 34 of Set 12 | matay
# Processing Record 35 of Set 12 | cape canaveral
# Processing Record 36 of Set 12 | sibolga
# Processing Record 37 of Set 12 | shingu
# Processing Record 38 of Set 12 | gigmoto
# Processing Record 39 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 12 | dourbali
# Processing Record 41 of Set 12 | ubinskoye
# Processing Record 42 of Set 12 | nacala
# Processing Record 43 of Set 12 | kostomuksha
# Processing Record 44 of Set 12 | tarime
# Processing Record 45 of Set 12 | lipany
# Processing Record 46 of Set 12 | tibati
# Processing Record 47 of Set 12 | paita
# Processing Record 48 of Set 12 | vardo
# Processing Record 49 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 12 | strezhevoy
# Processing Record 1 of Set 13 | pathein
# Processing Record 2 of Set 13 | indian head
# Processing Record 3 of Set 13 | mandera
# Processing Record 4 of Set 13 | baiyin
# Processing Record 5 of Set 13 | nemuro
# Processing Record 6 of Set 13 | barra
# Processing Record 7 of Set 13 | ljaskovec
# City not found. Skipping...
# Processing Record 8 of Set 13 | mahibadhoo
# Processing Record 9 of Set 13 | ancud
# Processing Record 10 of Set 13 | karratha
# Processing Record 11 of Set 13 | yuancheng
# Processing Record 12 of Set 13 | vanavara
# Processing Record 13 of Set 13 | jinka
# Processing Record 14 of Set 13 | lodja
# Processing Record 15 of Set 13 | zhigansk
# Processing Record 16 of Set 13 | sao joao da barra
# Processing Record 17 of Set 13 | atagay
# Processing Record 18 of Set 13 | bhitarwar
# Processing Record 19 of Set 13 | russell
# Processing Record 20 of Set 13 | okhotsk
# Processing Record 21 of Set 13 | dunedin
# Processing Record 22 of Set 13 | dese
# Processing Record 23 of Set 13 | palmer
# Processing Record 24 of Set 13 | coos bay
# Processing Record 25 of Set 13 | ornskoldsvik
# Processing Record 26 of Set 13 | makakilo city
# Processing Record 27 of Set 13 | canitas
# City not found. Skipping...
# Processing Record 28 of Set 13 | xuddur
# Processing Record 29 of Set 13 | la primavera
# Processing Record 30 of Set 13 | warrnambool
# Processing Record 31 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 13 | aden
# Processing Record 33 of Set 13 | wattegama
# Processing Record 34 of Set 13 | clovis
# Processing Record 35 of Set 13 | zhangjiakou
# Processing Record 36 of Set 13 | sidi ali
# Processing Record 37 of Set 13 | fergus falls
# Processing Record 38 of Set 13 | amot
# Processing Record 39 of Set 13 | imbituba
# Processing Record 40 of Set 13 | manubah
# City not found. Skipping...
# Processing Record 41 of Set 13 | fuyang
# Processing Record 42 of Set 13 | serenje
# Processing Record 43 of Set 13 | goiatuba
# Processing Record 44 of Set 13 | klyuchi
# Processing Record 45 of Set 13 | luan
# Processing Record 46 of Set 13 | mareeba
# Processing Record 47 of Set 13 | najran
# Processing Record 48 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 49 of Set 13 | san rafael
# Processing Record 50 of Set 13 | salamiyah
# Processing Record 1 of Set 14 | rion
# Processing Record 2 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 14 | lompoc
# Processing Record 4 of Set 14 | vanimo
# Processing Record 5 of Set 14 | santa clara
# Processing Record 6 of Set 14 | waingapu
# Processing Record 7 of Set 14 | sarangpur
# Processing Record 8 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 14 | camopi
# Processing Record 10 of Set 14 | egvekinot
# Processing Record 11 of Set 14 | mongo
# Processing Record 12 of Set 14 | kristiansund
# Processing Record 13 of Set 14 | honningsvag
# Processing Record 14 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 15 of Set 14 | coacoyul
# Processing Record 16 of Set 14 | san matias
# Processing Record 17 of Set 14 | villaviciosa
# Processing Record 18 of Set 14 | dawlatabad
# Processing Record 19 of Set 14 | wasilla
# Processing Record 20 of Set 14 | svetlyy
# Processing Record 21 of Set 14 | sargur
# Processing Record 22 of Set 14 | naryan-mar
# Processing Record 23 of Set 14 | moses lake
# Processing Record 24 of Set 14 | flin flon
# Processing Record 25 of Set 14 | malanville
# Processing Record 26 of Set 14 | poum
# Processing Record 27 of Set 14 | amapa
# Processing Record 28 of Set 14 | ende
# Processing Record 29 of Set 14 | remerschen
# Processing Record 30 of Set 14 | filadelfia
# Processing Record 31 of Set 14 | visby
# Processing Record 32 of Set 14 | kieta
# Processing Record 33 of Set 14 | colares
# Processing Record 34 of Set 14 | mogadishu
# Processing Record 35 of Set 14 | tarakan
# Processing Record 36 of Set 14 | tucurui
# Processing Record 37 of Set 14 | aksha
# Processing Record 38 of Set 14 | zyryanka
# Processing Record 39 of Set 14 | usinsk
# Processing Record 40 of Set 14 | inirida
# Processing Record 41 of Set 14 | shambu
# Processing Record 42 of Set 14 | alugan
# Processing Record 43 of Set 14 | karasburg
# Processing Record 44 of Set 14 | osinki
# Processing Record 45 of Set 14 | lorengau
# Processing Record 46 of Set 14 | kaili
# Processing Record 47 of Set 14 | elban
# Processing Record 48 of Set 14 | homer
# Processing Record 49 of Set 14 | longhua
# Processing Record 50 of Set 14 | peace river
# Processing Record 1 of Set 15 | coahuayana
# Processing Record 2 of Set 15 | sambava
# Processing Record 3 of Set 15 | lagos
# Processing Record 4 of Set 15 | mezhdurechensk
# Processing Record 5 of Set 15 | kismayo
# Processing Record 6 of Set 15 | nizhniy kuranakh
# Processing Record 7 of Set 15 | kushima
# Processing Record 8 of Set 15 | torbat-e jam
# Processing Record 9 of Set 15 | norcasia
# Processing Record 10 of Set 15 | koudougou
# Processing Record 11 of Set 15 | soavinandriana
# Processing Record 12 of Set 15 | nicoya
# Processing Record 13 of Set 15 | ashland
# Processing Record 14 of Set 15 | begunitsy
# Processing Record 15 of Set 15 | nuuk
# Processing Record 16 of Set 15 | rockhampton
# Processing Record 17 of Set 15 | nanakuli
# Processing Record 18 of Set 15 | tanggul
# Processing Record 19 of Set 15 | khorramshahr
# Processing Record 20 of Set 15 | la ronge
# Processing Record 21 of Set 15 | kemijarvi
# Processing Record 22 of Set 15 | kabwe
# Processing Record 23 of Set 15 | belle fourche
# Processing Record 24 of Set 15 | saravan
# Processing Record 25 of Set 15 | sakaiminato
# Processing Record 26 of Set 15 | somerset
# Processing Record 27 of Set 15 | huescar
# Processing Record 28 of Set 15 | keti bandar
# Processing Record 29 of Set 15 | metro
# Processing Record 30 of Set 15 | teya
# Processing Record 31 of Set 15 | lampazos de naranjo
# Processing Record 32 of Set 15 | denpasar
# Processing Record 33 of Set 15 | neiafu
# Processing Record 34 of Set 15 | blagoyevo
# Processing Record 35 of Set 15 | byron bay
# Processing Record 36 of Set 15 | yelizovo
# Processing Record 37 of Set 15 | aswan
# Processing Record 38 of Set 15 | reconquista
# Processing Record 39 of Set 15 | bridge city
# Processing Record 40 of Set 15 | cedar rapids
# Processing Record 41 of Set 15 | astoria
# Processing Record 42 of Set 15 | ferkessedougou
# Processing Record 43 of Set 15 | codrington
# Processing Record 44 of Set 15 | atambua
# Processing Record 45 of Set 15 | bud
# Processing Record 46 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 47 of Set 15 | jiangyin
# Processing Record 48 of Set 15 | parana
# Processing Record 49 of Set 15 | balbalan
# Processing Record 50 of Set 15 | ferrol
# Processing Record 1 of Set 16 | necochea
# Processing Record 2 of Set 16 | kenitra
# Processing Record 3 of Set 16 | halalo
# City not found. Skipping...
# Processing Record 4 of Set 16 | merauke
# Processing Record 5 of Set 16 | burns lake
# Processing Record 6 of Set 16 | gushikawa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 7. Add the data to a new dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Axim      GH   4.8699   -2.2405     76.96        89          92
# 1  Saint Anthony      US  45.0205  -93.2180     46.78        88           1
# 2        Rikitea      PF -23.1203 -134.9692     75.24        82          99
# 3         Karema      TZ  -6.8205   30.4389     74.23        71          70
# 4       Waverley      ZA -25.7023   28.2591     64.53        78           0
# 5            Oga      IT  46.4631   10.3470     30.69        48          24
# 6       Coquimbo      CL -29.9533  -71.3436     55.13        94          90
# 7       Hermanus      ZA -34.4187   19.2345     59.90        86          68
# 8        Mataura      NZ -46.1927  168.8643     74.32        39          78
# 9          Airai      TL  -8.9266  125.4092     81.18        38          99
#
#    Wind Speed Current Description
# 0        5.57          light rain
# 1        0.00           clear sky
# 2       16.11          light rain
# 3        4.59          light rain
# 4        4.27           clear sky
# 5        6.26          few clouds
# 6        3.44     overcast clouds
# 7        1.95       broken clouds
# 8        4.18       broken clouds
# 9        2.15     overcast clouds

# %%
# 8. Export into a CSV

output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="WeatherPy_Database")
